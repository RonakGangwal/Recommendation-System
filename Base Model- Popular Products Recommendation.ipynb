# %% [markdown]
# # Recommending most Popular Products of the Bank

# %%
#importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook as tqdm
from IPython.display import display
pd.options.display.max_columns = None
import datetime
import warnings                               # To ignore any warnings 
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv('train_trea')
test=pd.read_csv('test_trea')

# %%
last_mon=train[train['fecha_dato']=='2016-05-28']

# %%
pop_pro=last_mon[['ncodpers','ind_cco_fin_ult1','ind_recibo_ult1','ind_ctop_fin_ult1','ind_ecue_fin_ult1','ind_cno_fin_ult1','ind_nom_pens_ult1','ind_nomina_ult1','ind_reca_fin_ult1','ind_tjcr_fin_ult1','ind_ctpp_fin_ult1','ind_dela_fin_ult1','ind_valo_fin_ult1','ind_fond_fin_ult1','ind_ctma_fin_ult1','ind_ctju_fin_ult1','ind_plan_fin_ult1','ind_hip_fin_ult1','ind_viv_fin_ult1']]

# %%
pop_pro.shape
# Out:
# (931453, 19)

# %%
df=pd.DataFrame()

# %%
df=pop_pro[pop_pro.iloc[:,1:19]==0.0]

# %%
df
# Out:
#           ncodpers  ind_cco_fin_ult1  ind_recibo_ult1  ind_ctop_fin_ult1  \
# 12715856       NaN               0.0              0.0                0.0
# 12715857       NaN               NaN              0.0                0.0
# 12715858       NaN               NaN              0.0                0.0
# 12715859       NaN               0.0              NaN                0.0
# 12715860       NaN               NaN              0.0                0.0
# 12715861       NaN               0.0              0.0                0.0
# 12715862       NaN               NaN              0.0                0.0
# 12715863       NaN               NaN              0.0                0.0
# 12715864       NaN               NaN              0.0                0.0
# 12715865       NaN               0.0              0.0                0.0
# 12715866       NaN               0.0              0.0                0.0
# 12715867       NaN               NaN              0.0                0.0
# ...

# %%
df.ncodpers=df.ncodpers.fillna(pop_pro['ncodpers'])

# %%
df.head()
# Out:
#           ncodpers  ind_cco_fin_ult1  ind_recibo_ult1  ind_ctop_fin_ult1  \
# 12715856  657640.0               0.0              0.0                0.0
# 12715857  657788.0               NaN              0.0                0.0
# 12715858  657795.0               NaN              0.0                0.0
# 12715859  657790.0               0.0              NaN                0.0
# 12715860  657794.0               NaN              0.0                0.0
#
#           ind_ecue_fin_ult1  ind_cno_fin_ult1  ind_nom_pens_ult1  \
# 12715856                0.0               0.0                0.0
# 12715857                0.0               0.0                0.0
# 12715858                0.0               0.0                0.0
# 12715859                NaN               NaN                NaN
# 12715860                0.0               0.0                0.0
#
#           ind_nomina_ult1  ind_reca_fin_ult1  ind_tjcr_fin_ult1  \
# 12715856              0.0                0.0                0.0
# ...

# %%
df_melt=pd.melt(df,id_vars =['ncodpers'],value_vars =['ind_cco_fin_ult1','ind_recibo_ult1','ind_ctop_fin_ult1','ind_ecue_fin_ult1','ind_cno_fin_ult1','ind_nom_pens_ult1','ind_nomina_ult1','ind_reca_fin_ult1','ind_tjcr_fin_ult1','ind_ctpp_fin_ult1','ind_dela_fin_ult1','ind_valo_fin_ult1','ind_fond_fin_ult1','ind_ctma_fin_ult1','ind_ctju_fin_ult1','ind_plan_fin_ult1','ind_hip_fin_ult1','ind_viv_fin_ult1'])

# %%
df_melt.head()
# Out:
#    ncodpers          variable  value
# 0  657640.0  ind_cco_fin_ult1    0.0
# 1  657788.0  ind_cco_fin_ult1    NaN
# 2  657795.0  ind_cco_fin_ult1    NaN
# 3  657790.0  ind_cco_fin_ult1    0.0
# 4  657794.0  ind_cco_fin_ult1    NaN

# %%
to_rec=df_melt[df_melt['value']==0.0]

# %%
to_rec.shape
# Out:
# (15529355, 3)

# %%
list_pro=to_rec.groupby('ncodpers')['variable'].apply(list)

list_pro=list_pro.reset_index()

# %%
list_pro.ncodpers=list_pro.ncodpers.astype(int)

# %%
list_pro.ncodpers=list_pro.ncodpers.astype(int)
list_pro.variable=list_pro.variable.apply(lambda l: " ".join(l))
list_pro.variable=list_pro.variable.apply(lambda l:l.split(' ',7)[0:7])

# %%
list_pro.variable=list_pro.variable.apply(lambda l: " ".join(l))

list_pro.dtypes

# %%
list_pro.head()

ny.variable=ny.variable.apply(lambda l: " ".join(l))

ny.head()

# %%
ny.variable=ny.variable.apply(lambda l:l.split(' ',7)[0:7])

ny.variable=ny.variable.apply(lambda l: " ".join(l))

# %%
display(ny.head())

li=test['ncodpers']

# %%
li

li[100]

fin=ny[ny['ncodpers'].isin(li)]

# %%
fin.head()

fin.to_csv('popular_pro.csv')

# %%
fin.shape

test.shape

# %%
test[test['ncodpers']==15990]

ny.iloc[:,0]

# %%
pop_pro=pd.read_csv('popular_pro.csv')

# %%
pop_pro = pop_pro.set_index('ncodpers')

# %%
pop_pro.head()

# %%
pop_pro = pop_pro.reindex(index=test['ncodpers'])

# %%
pop_pro = pop_pro.reset_index()

pop_pro.shape

# %%
pop_pro=pop_pro.drop('Unnamed: 0',axis=1)

pop_pro.shape

# %%
pop_pro.to_csv('final.csv')

# %%
last_mon.to_csv('last_month_trea')
